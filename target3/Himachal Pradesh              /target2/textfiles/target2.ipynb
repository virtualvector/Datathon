# %%
import json

import codecs
import csv
import os
import re
import sys
import collections
import glob
ipath = 'C:/TEMP/' # input folder
opath = 'C:/TEMP/matrix/' # output folder
reader = codecs.getreader("utf-8")
path = 'C:/TEMP/*.txt'   
file = glob.glob(path)
text = file.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-650546dda622> in <module>()
#      13 path = 'C:/TEMP/*.txt'
#      14 file = glob.glob(path)
# ---> 15 text = file.read()
#
# AttributeError: 'list' object has no attribute 'read'

# %%
pp=!ls
dum=pp[0]

# %%
pp
# Out:
# ['bilaspur (h.p.) Class - 3 (Mathematics).txt',
#  'bilaspur (h.p.) Class - 5 (Mathematics).txt',
#  'bilaspur (h.p.) Class - 8 (Mathematics).txt',
#  'chamba Class - 3 (Mathematics).txt',
#  'chamba Class - 5 (Mathematics).txt',
#  'chamba Class - 8 (Mathematics).txt',
#  'hamirpur (h.p.) Class - 3 (Mathematics).txt',
#  'hamirpur (h.p.) Class - 5 (Mathematics).txt',
#  'hamirpur (h.p.) Class - 8 (Mathematics).txt',
#  'kangra Class - 3 (Mathematics).txt',
#  'kangra Class - 5 (Mathematics).txt',
#  'kangra Class - 8 (Mathematics).txt',
#  'kinnaur Class - 3 (Mathematics).txt',
#  'kinnaur Class - 5 (Mathematics).txt',
#  'kinnaur Class - 8 (Mathematics).txt',
#  'kulu-class-3.txt',
#  'kulu-class-5.txt',
#  'kulu-class-8.txt',
#  'lahul-class-3.txt',
#  'lahul-class-5.txt',
#  'lahul-class-8.txt',
#  'mandi-class-3.txt',
#  'mandi-class-5.txt',
#  'mandi-class-8.txt',
#  'shimla-class-3.txt',
#  'shimla-class-5.txt',
#  'shimla-class-8.txt',
#  'simaur-class-3.txt',
# ...

# %%
with open(dum,'r') as f:
    print f.readlines()[48]
# Out:
# 69.72Performance on Learning Outcomes (LOs)

# %%
my_file = open(pp,'r')
data_list = my_file.readlines()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-96d88bfe7dc7> in <module>()
# ----> 1 my_file = open(pp,'r')
#       2 data_list = my_file.readlines()
#
# TypeError: coercing to Unicode: need string or buffer, SList found

# %%
my_list = [4,6,5,13,17,25,41,46,48]

# %%
appender=list()

# %%
for i in my_list:
    curr_data = data_list[i]
    
    if(i==4):
        curr_data.split(':')
        print curr_data
# Out:
# State: Himachal Pradesh District: Bilaspur (h.p.)
#
# Schools: 61 Students: 517
#
# Class: 3 Subject: Mathematics
#
# 267 51.64 250 48.36
#
# 486 94.00 31 6.00
#
# 196 37.91 33 6.38 35 6.77 253 48.94
#
# 66.67 65.81 65.88 72.04 66.25 0.00
#
# 69.72Performance on Learning Outcomes (LOs)

# %%
for i in my_list:
    curr_data = data_list[i]
    
    if(i==4):
        curr_data=curr_data.strip().split(':')
        appender.append(curr_data[-1])
        print curr_data[-1]
        
    if(i==6):
        curr_data=curr_data.strip().split()
        print curr_data[1]
        appender.append(curr_data[1])
        
    if(i==5):
        curr_data=curr_data.strip().split()
        print curr_data
        appender.append(curr_data[3])
        appender.append(curr_data[1])
        print curr_data[3],curr_data[1]
        
    if(i==13):
        curr_data=curr_data.strip().split()
        appender.append(curr_data[0])
        appender.append(curr_data[2])
        print curr_data[0],curr_data[2]
        
    if(i==17):
        curr_data=curr_data.strip().split()
        print curr_data
        appender.append(curr_data[0])
        appender.append(curr_data[2])
        print curr_data[0],curr_data[2]
        
    if(i==25):
        curr_data=curr_data.strip().split()
        print curr_data
        appender.append(curr_data[0])
        appender.append(curr_data[2])
        appender.append(curr_data[4])
        appender.append(curr_data[6])
        print curr_data[0],curr_data[2],curr_data[4],curr_data[6]
        
    if(i==41):
        curr_data=curr_data.strip().split()
        print curr_data
        appender.append(curr_data[0])
        appender.append(curr_data[1])
        appender.append(curr_data[2])
        appender.append(curr_data[3])
        
        
        
    if(i==46):
        curr_data=curr_data.strip().split()
        print curr_data
        appender.append(curr_data[0])
        appender.append(curr_data[1])
        appender.append(curr_data[2])
        print curr_data[0],curr_data[1],curr_data[2]
        
    if(i==48):
        curr_data=curr_data.strip().split()
        print curr_data[0][:5]
        appender.append(curr_data[0][:5])
# Out:
#  Bilaspur (h.p.)
# 61
# ['Class:', '3', 'Subject:', 'Mathematics']
# Mathematics 3
# 267 250
# ['486', '94.00', '31', '6.00']
# 486 31
# ['196', '37.91', '33', '6.38', '35', '6.77', '253', '48.94']
# 196 33 35 253
# ['66.67', '65.81', '65.88', '72.04', '66.25', '0.00']
# ['61.94', '61.01', '70.29']
# 61.94 61.01 70.29
# 69.72

# %%
len(appender)
# Out:
# 20

# %%
final_app=[]

# %%
def func()

# %%
for iter_file in pp:
    appender=list()
    my_file = open(iter_file,'r')
    data_list = my_file.readlines()
    
    for i in my_list:
        try:
            curr_data = data_list[i]
        
        

            if(i==4):
                curr_data=curr_data.strip().split(':')
                appender.append(curr_data[-1])
                print curr_data[-1]

            if(i==6):
                curr_data=curr_data.strip().split()
                print curr_data[1]
                appender.append(curr_data[1])

            if(i==5):
                curr_data=curr_data.strip().split()
                print curr_data
                appender.append(curr_data[3])
                appender.append(curr_data[1])
                print curr_data[3],curr_data[1]

            if(i==13):
                curr_data=curr_data.strip().split()
                appender.append(curr_data[0])
                appender.append(curr_data[2])
                print curr_data[0],curr_data[2]

            if(i==17):
                curr_data=curr_data.strip().split()
                print curr_data
                appender.append(curr_data[0])
                appender.append(curr_data[2])
                print curr_data[0],curr_data[2]

            if(i==25):
                curr_data=curr_data.strip().split()
                print curr_data
                appender.append(curr_data[0])
                appender.append(curr_data[2])
                appender.append(curr_data[4])
                appender.append(curr_data[6])
                print curr_data[0],curr_data[2],curr_data[4],curr_data[6]

            if(i==41):
                curr_data=curr_data.strip().split()
                print curr_data
                appender.append(curr_data[0])
                appender.append(curr_data[1])
                appender.append(curr_data[2])
                appender.append(curr_data[3])



            if(i==46):
                curr_data=curr_data.strip().split()
                print curr_data
                appender.append(curr_data[0])
                appender.append(curr_data[1])
                appender.append(curr_data[2])
                print curr_data[0],curr_data[1],curr_data[2]

            if(i==48):
                curr_data=curr_data.strip().split()
                print curr_data[0][:5]
                appender.append(curr_data[0][:5])
                
 
                
        except Exception as e:
            pass
        
        final_app.append(appender)
# Out:
#  Bilaspur (h.p.)
# 61
# ['Class:', '3', 'Subject:', 'Mathematics']
# Mathematics 3
# 267 250
# ['486', '94.00', '31', '6.00']
# 486 31
# ['196', '37.91', '33', '6.38', '35', '6.77', '253', '48.94']
# 196 33 35 253
# ['66.67', '65.81', '65.88', '72.04', '66.25', '0.00']
# ['61.94', '61.01', '70.29']
# 61.94 61.01 70.29
# 69.72
#  Bilaspur (h.p.)
# 61
# ['Class:', '5', 'Subject:', 'Mathematics']
# Mathematics 5
# 282 289
# ['519', '90.89', '52', '9.11']
# 519 52
# ['195', '34.15', '18', '3.15', '48', '8.41', '310', '54.29']
# 195 18 48 310
# ['49.34', '50.63', '50.06', '49.36', '49.99', '0.00']
# ['51.49', '44.44', '50.28']
# 51.49 44.44 50.28
# 49.33
#  Bilaspur (h.p.)
# 51
# ['Class:', '8', 'Subject:', 'Mathematics']
# Mathematics 8
# 472 496
# ['905', '93.49', '63', '6.51']
# 905 63
# ['324', '33.47', '26', '2.69', '69', '7.13', '549', '56.71']
# 324 26 69 549
# ['35.59', '34.57', '35.27', '32.17', '35.07', '0.00']
# ['34.20', '41.03', '31.98']
# 34.20 41.03 31.98
# 35.69
#  Chamba
# ...

# %%
appender
# Out:
# [' Bilaspur (h.p.)',
#  '61',
#  'Mathematics',
#  '3',
#  '267',
#  '250',
#  '486',
#  '31',
#  '196',
#  '33',
#  '35',
#  '253',
#  '66.67',
#  '65.81',
#  '65.88',
#  '72.04',
#  '61.94',
#  '61.01',
#  '70.29',
#  '69.72',
#  ' Bilaspur (h.p.)',
#  '61',
#  'Mathematics',
#  '5',
#  '282',
#  '289',
#  '519',
#  '52',
#  '195',
#  '18',
#  '48',
#  '310',
#  '49.34',
#  '50.63',
#  '50.06',
#  '49.36',
#  '51.49',
#  '44.44',
#  '50.28',
#  '49.33',
#  ' Bilaspur (h.p.)',
#  '51',
#  'Mathematics',
#  '8',
#  '472',
#  '496',
#  '905',
#  '63',
#  '324',
#  '26',
#  '69',
#  '549',
#  '35.59',
#  '34.57',
#  '35.27',
#  '32.17',
#  '34.20',
#  '41.03',
#  '31.98',
#  '35.69',
#  ' Chamba',
#  '61',
#  'Mathematics',
#  '3',
#  '275',
#  '339',
#  'Number',
#  'Number',
#  'Number',
#  'Number',
#  'Number',
#  'Number',
#  'Male',
#  'Female',
#  'Rural',
#  'Urban',
#  'OBC',
#  ' Bilaspur (h.p.)',
#  '61',
#  'Mathematics',
#  '3',
#  '267',
#  '250',
#  '486',
#  '31',
# ...

# %%
for i in final_app:
    print i
# Out:
# [' Bilaspur (h.p.)', '61', 'Mathematics', '3', '267', '250', '486', '31', '196', '33', '35', '253', '66.67', '65.81', '65.88', '72.04', '61.94', '61.01', '70.29', '69.72']
# [' Bilaspur (h.p.)', '61', 'Mathematics', '3', '267', '250', '486', '31', '196', '33', '35', '253', '66.67', '65.81', '65.88', '72.04', '61.94', '61.01', '70.29', '69.72']
# [' Bilaspur (h.p.)', '61', 'Mathematics', '3', '267', '250', '486', '31', '196', '33', '35', '253', '66.67', '65.81', '65.88', '72.04', '61.94', '61.01', '70.29', '69.72']
# [' Bilaspur (h.p.)', '61', 'Mathematics', '3', '267', '250', '486', '31', '196', '33', '35', '253', '66.67', '65.81', '65.88', '72.04', '61.94', '61.01', '70.29', '69.72']
# [' Bilaspur (h.p.)', '61', 'Mathematics', '3', '267', '250', '486', '31', '196', '33', '35', '253', '66.67', '65.81', '65.88', '72.04', '61.94', '61.01', '70.29', '69.72']
# ...

# %%
with open ('CAD18_06_target_1.csv','w') as ff:
    for k in final_app:
        string = ",".join(k)
        string+="\n"
        ff.write(string)
