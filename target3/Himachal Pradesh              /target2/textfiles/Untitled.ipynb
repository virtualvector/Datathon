# %%
import slate

# %%
pdf = 'mewat Class - 3 (Language)  Report Card.pdf'

# %%
with open(pdf) as f:
    doc = slate.PDF(f)
for page in doc[:2]:
    print page
# Out:
# NATIONAL COUNCIL OF EDUCATIONAL RESEARCH AND TRAINING
#
# NATIONAL ACHIEVEMENT SURVEY - NAS
#
# (Survey of Learning Outcomes)
#
# State: Haryana
#
# Class: 3
#
# Schools: 61
#
# Students
#
# GENDER
#
# AREA
#
# CATEGORY
#
# CWSN
#
# District Report Card: 2017
#
# District: Mewat
#
# Subject: Language
#
# Students: 1446
#
# Participation/Coverage
#
# Boys
#
# Rural
#
# Number
#
# 738
#
# Number
#
# 1395
#
# SC
#
# %
#
# 51.04
#
# %
#
# 96.47
#
# ST
#
# Girls
#
# Urban
#
# Number
#
# 708
#
# Number
#
# 51
#
# OBC
#
# %
#
# 48.96
#
# %
#
# 3.53
#
# GEN
#
# Number
#
# %
#
# Number
#
# %
#
# Number
#
# %
#
# Number
#
# %
#
# 91
#
# 6.29
#
# 1
#
# 0.07
#
# 1304
#
# 90.18
#
# 50
#
# 3.46
#
# LD
#
# 4
#
# VI
#
# 9
#
# HI
#
# 0
#
# S&LD
#
# 2
#
# ID
#
# 1
#
# Oth
#
# 105
#
# %
#
# 0.00
#
# Management
#
# Government
#
# Government-aided
#
# Number
#
# 1446
#
# %
#
# 100.00
#
# Number
#
# 0
#
# Average Performance of Students in Language (%)
#
# Gender
#
# Area
#
# Management
#
# Social Group
# ...

# %%
# Out:
# bilaspur (h.p.) Class - 3 (Mathematics).txt  lahul-class-3.txt
# bilaspur (h.p.) Class - 5 (Mathematics).txt  lahul-class-5.txt
# bilaspur (h.p.) Class - 8 (Mathematics).txt  lahul-class-8.txt
# CAD18_06_target_1 (copy).xlsx		     mandi-class-3.txt
# CAD18_06_target_1.csv			     mandi-class-5.txt
# CAD18_06_target_1.txt			     mandi-class-8.txt
# chamba Class - 3 (Mathematics).txt	     shimla-class-3.txt
# chamba Class - 5 (Mathematics).txt	     shimla-class-5.txt
# chamba Class - 8 (Mathematics).txt	     shimla-class-8.txt
# hamirpur (h.p.) Class - 3 (Mathematics).txt  simaur-class-3.txt
# hamirpur (h.p.) Class - 5 (Mathematics).txt  simaur-class-5.txt
# hamirpur (h.p.) Class - 8 (Mathematics).txt  simaur-class-8.txt
# hello-world.pdf				     solan-clas-8.txt
# kangra Class - 3 (Mathematics).txt	     solan-class-3.txt
# kangra Class - 5 (Mathematics).txt	     solan-class-5.txt
# kangra Class - 8 (Mathematics).txt	     target2.ipynb
# ...
